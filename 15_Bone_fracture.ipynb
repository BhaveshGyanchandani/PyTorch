# %%
yolo detect train data="D:\web dev backup\Pytorch\Bone fracture detection.v1i.yolov8\data.yaml" model=yolov8n.pt epochs=50 imgsz=640 batch=8
# Out:
# UsageError: Line magic function `%yolo` not found.

# %%
Speed: 1.7ms preprocess, 55.9ms inference, 0.0ms loss, 0.5ms postprocess per image
Results saved to D:\web dev backup\runs\detect\train3
 Learn more at https://docs.ultralytics.com/modes/train

# %%
yolo detect train data="D:\web dev backup\Pytorch\Bone fracture detection.v1i.yolov8\data.yaml" \
model="D:\web dev backup\runs\detect\train3\weights\last.pt" epochs=20 imgsz=640 batch=8

# %%
yolo detect train resume model="D:\web dev backup\runs\detect\train3\weights\last.pt"

# %%
yolo detect train data="D:\web dev backup\Pytorch\Bone fracture detection.v1i.yolov8\data.yaml" `
model="D:\web dev backup\runs\detect\train3\weights\last.pt" `
epochs=40 imgsz=640 batch=8

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
Results saved to D:\web dev backup\Pytorch\runs\detect\train
