        "https://www.youtube.com/watch?v=s5fUlMRjmx8", "https://www.youtube.com/watch?v=3tmd-ClpJxA", 
        "https://www.youtube.com/watch?v=eH6BBjwG3uk", "https://www.youtube.com/watch?v=mLckpEKzFfc", 
        "https://www.youtube.com/watch?v=KUK8k7i1S5k", "https://www.youtube.com/watch?v=RbZjHpG55CA", 
        "https://www.youtube.com/watch?v=6g4HD1tyKAs", "https://www.youtube.com/watch?v=REle7TkHk9Y", 
        "https://www.youtube.com/watch?v=eH6BBjwG3uk", "https://www.youtube.com/watch?v=mLckpEKzFfc", 
        "https://www.youtube.com/watch?v=KUK8k7i1S5k", "https://www.youtube.com/watch?v=RbZjHpG55CA", 
        "https://www.youtube.com/watch?v=6g4HD1tyKAs"

    ],
    "singer": [
        "Ed Sheeran", "Luis Fonsi", "Adele", "Enrique Iglesias", "The Weeknd", 
        "Adele", "Pharrell Williams", "Ritchie Valens", "John Legend", "J Balvin", 
        "Mark Ronson", "Maroon 5", "The Beatles", "Ed Sheeran", "Katy Perry", 
        "Taylor Swift", "Camila Cabello", "Ed Sheeran", "Zayn Malik", "One Direction", 
        "Eminem", "Psy", "OneRepublic", "Adele", "Ed Sheeran", 
        "Tones and I", "Major Lazer", "The Black Eyed Peas", "Ellie Goulding", "Lady Gaga", 
        "Katy Perry", "Gotye", "Adele", "Lady Gaga", "Sia", "Justin Timberlake", 
        "Luis Fonsi", "Marshmello", "Coldplay", "Hozier", "Lil Nas X", "James Arthur", 
        "Ed Sheeran", "Passenger", "Bruno Mars", "Rihanna", "David Guetta", 
        "OneRepublic", "Jason Mraz", "Bruno Mars", "Ed Sheeran", "The Chainsmokers", 
        "Ed Sheeran"
    ],
    "language": [
        "English", "Spanish", "English", "Spanish", "English", 
        "English", "English", "Spanish", "English", "Spanish", 
        "English", "English", "English", "English", "English", 
        "English", "Spanish", "English", "English", "English", 
        "English", "Korean", "English", "English", "English", 
        "English", "English", "English", "English", "English", 
        "English", "English", "English", "English", "English", 
        "English", "English", "English", "English", "English", 
        "English", "English", "English", "English", "English", 
        "English", "English", "English", "English", "English", 
        "English", "English", "English"
    ],
    "emotion": [
        "Happy", "Sad", "Sad", "Happy", "Happy", 
        "Sad", "Happy", "Happy", "Romantic", "Happy",
        "Happy", "Happy", "Sad", "Happy", "Excited", 
        "Happy", "Happy", "Romantic", "Happy", "Upbeat", 
        "Motivational", "Energetic", "Energetic", "Sad", "Energetic", 
        "Happy", "Sad", "Energetic", "Sad", "Happy", 
        "Happy", "Sad", "Sad", "Energetic", "Happy", 
        "Sad", "Happy", "Energetic", "Sad", "Energetic", 
        "Sad", "Sad", "Happy", "Sad", "Energetic", 
        "Romantic", "Happy", "Happy", "Sad", "Sad", 
        "Energetic", "Happy", "Sad"
    ]
}


import pandas as pd
import os

# Specify the path to your songs.csv file
file_path = 'songs.csv'

# Check if the file exists, then remove it
if os.path.exists(file_path):
    os.remove(file_path)
    print(f"{file_path} has been deleted successfully.")
else:
    print(f"{file_path} does not exist.")
    

# Create DataFrame from the data
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('songs.csv', index=False)

print("Dataset created and saved as 'songs.csv'")
# Out:
# songs.csv does not exist.
# Dataset created and saved as 'songs.csv'

# %%
# Checking the length of each list in the data dictionary
for key, value in data.items():
    print(f"Length of {key}: {len(value)}")
# Out:
# Length of Song_name: 53
# Length of Song_URL_on_Youtube: 53
# Length of singer: 53
# Length of language: 53
# Length of emotion: 53
